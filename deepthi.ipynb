# %%
import ollama

model = "llama3:8b"

def ask_llm(inp):

    rules = """
    You are a professional Financial Assistant.

    Responsibilities:
    - Help users create budgets and savings plans.
    - Explain financial concepts in simple language.
    - Provide investment education.
    - Assist with debt repayment strategies.
    - Help calculate interest, EMI, returns, and expenses.
    - Suggest ways to reduce spending and improve savings habits.

    Rules:
    - Never claim to be a licensed financial advisor.
    - Do not guarantee profits or returns.
    - Mention risks associated with investments.
    - Avoid legal and tax advice.
    - Keep responses simple and practical.
    """

    response = ollama.chat(
        model=model,
        messages=[
            {
                "role": "system",
                "content": rules
            },
            {
                "role": "user",
                "content": inp
            }
        ],
        stream=True
    )

    for res in response:
        print(res["message"]["content"], end="", flush=True)

    print("\n")


while True:
    inp = input("Enter your financial question: ")

    if inp.lower() in ["exit", "quit"]:
        print("Goodbye!")
        break

    ask_llm(inp)

# %%
from langchain_community.document_loaders import PyPDFLoader

FILE_PATH = r"C:\Users\admin\Downloads\pradeepthi.pdf"

loader = PyPDFLoader(FILE_PATH)
docs = loader.load()

print(docs[0].page_content)
# Out:
# KACHHALLA DEEPTHI
# ♂phone+91 7396381295♂¶ap-¶arker-altVisakhapatnam, Andhra Pradesh
# /envel⌢pekachhalladeepthi@gmail.com/linkedinLinkedIn/codeCodeChef
# PROFESSIONAL SUMMARY
# Detail-oriented B.Tech Information Technology student with strong foundations in Data Structures, Algo-
# rithms, OOPs, and DBMS. Proficient in Java, MySQL, and web technologies with hands-on project experience.
# Passionate about problem-solving and building efficient real-world applications.
# EDUCATION
# Vignan’s Institute of Engineering for W omen, Visakhapatnam Expected 2027
# Bachelor of Technology in Information Technology CGPA: 8.99
# Sri Chaitanya Junior College 2020 – 2022
# Board of Intermediate Education, Andhra Pradesh Percentage: 89%
# Rama School of Excellence 2020
# Board of Secondary Education, Andhra Pradesh Percentage: 85%
# TECHNICAL SKILLS
# •Programming Languages:Java, C
# •W eb T echnologies:HTML5, CSS3, JavaScript
# •Database T echnologies:MySQL, SQL
# •Core Concepts:Data Structures, Algorithms, OOPs, DBMS, Operating Systems
# •T ools & Platforms:Git, GitHub, VS Code
# PROJECTS
# F ood for All – Donation Management SystemHTML, CSS, JavaScript, MySQL
# •Developed a responsive donation management web application to connect donors and receivers efficiently.
# •Implemented structured request handling and user-friendly interfaces using HTML, CSS, and JavaScript.
# •Improved data organization and contribution tracking for better management of donation requests.
# F arm2F ork Ledger – F armer-to-Consumer Supply Chain PlatformHTML, CSS, JavaScript
# •Designed and developed a web-based platform connecting farmers directly with consumers.
# •Implemented dynamic product listing, ordering workflows, and location-based filtering features.
# •Enhanced user interaction and data handling through efficient frontend and database integration.
# CODING PROFILES
# •Solved 200+ coding problems on CodeChef demonstrating strong problem-solving and algorithmic skills.
# •Regularly participated in coding contests to improve programming and analytical abilities.
# CERTIFICATIONS
# •C Programming Certification – Infosys Springboard
# •Java Programming – NPTEL
# •Programming Using Java – Infosys Springboard

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=300,
    chunk_overlap=60
)
texts = text_splitter.split_documents(docs)

# %%
print(texts[0])
print(texts[1])
# Out:
# page_content='KACHHALLA DEEPTHI
# ♂phone+91 7396381295♂¶ap-¶arker-altVisakhapatnam, Andhra Pradesh
# /envel⌢pekachhalladeepthi@gmail.com/linkedinLinkedIn/codeCodeChef
# PROFESSIONAL SUMMARY
# Detail-oriented B.Tech Information Technology student with strong foundations in Data Structures, Algo-' metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-06-09T12:04:46+00:00', 'author': '', 'keywords': '', 'moddate': '2026-06-09T12:04:46+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.27 (TeX Live 2025) kpathsea version 6.4.1', 'subject': '', 'title': '', 'trapped': '/False', 'source': 'C:\\Users\\admin\\Downloads\\pradeepthi.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}
# page_content='rithms, OOPs, and DBMS. Proficient in Java, MySQL, and web technologies with hands-on project experience.
# Passionate about problem-solving and building efficient real-world applications.
# EDUCATION
# Vignan’s Institute of Engineering for W omen, Visakhapatnam Expected 2027' metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-06-09T12:04:46+00:00', 'author': '', 'keywords': '', 'moddate': '2026-06-09T12:04:46+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.27 (TeX Live 2025) kpathsea version 6.4.1', 'subject': '', 'title': '', 'trapped': '/False', 'source': 'C:\\Users\\admin\\Downloads\\pradeepthi.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}

# %%
model="BAAI/bge-large-en-v1.5"

# %%
from langchain_huggingface import HuggingFaceEmbeddings
embeddings= HuggingFaceEmbeddings(model_name="BAAI/bge-large-en-v1.5")
# Out:
# Loading weights:   0%|          | 0/391 [00:00<?, ?it/s]

# %%
from langchain_chroma import Chroma
vector_store = Chroma(
    collection_name = "sample_RAG",
    embedding_function=embeddings,
persist_directory = "./chroma_langchain_db",
)

# %%
vector_store._collection.count()
# Out:
# 6

# %%
from langchain_community.vectorstores.utils import filter_complex_metadata
texts = filter_complex_metadata(texts)

# %%
texts[0]
# Out:
# Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-06-09T12:04:46+00:00', 'author': '', 'keywords': '', 'moddate': '2026-06-09T12:04:46+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.27 (TeX Live 2025) kpathsea version 6.4.1', 'subject': '', 'title': '', 'trapped': '/False', 'source': 'C:\\Users\\admin\\Downloads\\pradeepthi.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='KACHHALLA DEEPTHI\n♂phone+91 7396381295♂¶ap-¶arker-altVisakhapatnam, Andhra Pradesh\n/envel⌢pekachhalladeepthi@gmail.com/linkedinLinkedIn/codeCodeChef\nPROFESSIONAL SUMMARY\nDetail-oriented B.Tech Information Technology student with strong foundations in Data Structures, Algo-')

# %%
vector_store.add_documents(texts)
# Out:
# ['8f5f4fe6-dec2-4000-ba4f-3014699cb74a',
#  'd0eea4dd-5185-48ac-91ac-88b8f754b4ee',
#  '6bbf18be-edaf-4597-a0bf-84cfbf17dbff',
#  'e12cf052-2613-4032-acac-f223b489ab9d',
#  '35d14b93-b12b-4c62-858f-5f9700e3b813',
#  'a63e0b12-61bc-44bd-988c-1316a31a01cb',
#  '58f4c9b8-0544-4636-886a-3a30988f8f3d',
#  'e53fdb4d-31b5-43fc-8a2c-c6709c8be6c4',
#  '8498a4bd-73fb-4838-8ebd-b9170f8037a2']

# %%
vector_store._collection.count()
# Out:
# 15

# %%
vector_store._collection.get(ids = ['da60798f-2f26-42dd-823b-eef487a821f7'], include = ["embeddings","documents"])
# Out:
# {'ids': [],
#  'embeddings': array([], dtype=float64),
#  'documents': [],
#  'uris': None,
#  'included': ['embeddings', 'documents'],
#  'data': None,
#  'metadatas': None}
